# %% [markdown]
# Validation of the second step:
#
# $$\frac{U^{**} - U^*}{\Delta t} = \frac{1}{Re} \nabla^2 U^{**}$$
#
# The reference solution is:
#
# \begin{equation}
# u(x) = \cos(2.0 \pi x) \cdot \sin(4.0 \pi y) \cdot \sin(8.0 \pi z)
# \end{equation}
#
# Source calculated for benchmarking is:
#
# \begin{equation}
# f(x, y, z) = -84 \pi^2 \cos(2.0 \pi x) \sin(4.0 \pi y) \sin(8.0 \pi z) - 1000 \cos(2.0 \pi x) \sin(4.0 \pi y) \sin(8.0 \pi z)
# \end{equation}
#
# Same {u, f} applied to (u, v, w)

# %%
#LAPLACIAN_X CONVERGENCE PLOT Re  = 10, delta_t = 0.01, N = 20, 40, 80, 160

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 160])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0415304, 0.010555, 0.00263993, 0.000658802])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
#LAPLACIAN_Y CONVERGENCE PLOT Re  = 10, delta_t = 0.01, N = 20, 40, 80, 160

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 160])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0401252, 0.0100937, 0.00251557, 0.000627275])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
#LAPLACIAN_Z CONVERGENCE PLOT Re  = 10, delta_t = 0.01, N = 20, 40, 80, 160

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 160])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0468644, 0.0115461, 0.00285358, 0.000708576])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
##Speed-up test laplaciano
import matplotlib.pyplot as plt

# Given data (execution times and number of processors)
execution_times = [2.17353, 1.63224, 1.61538, 1.27049]
processors = [1, 2, 3, 4]

# Calculate speedup relative to 1 processor
speedup = [execution_times[0] / time for time in execution_times]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(processors, speedup, marker='o', linestyle='-', color='b', linewidth=2, markersize=8)
plt.xlabel('Number of Processors')
plt.ylabel('Speedup')
plt.title('Speedup vs. Number of Processors')
plt.grid(True)
plt.xticks(processors)
plt.yticks([1] + speedup)  # Include 1 as a tick on the y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# Validation of the pressure problem:
#
# $$\nabla^2 P^{n+1} = \frac{1}{\Delta t} F^n$$
#
# The reference solution for P is (must respect homo-Neumann bc's):
#
# \begin{equation}
# u(x) = \cos(2.0 \pi x) \cdot \sin(4.0 \pi y) \cdot \sin(8.0 \pi z)
# \end{equation}
#
# Source calculated for benchmarking is:
#
# \begin{equation}
# f(x, y, z) = -84 \pi^2 \cos(2.0 \pi x) \sin(4.0 \pi y) \sin(8.0 \pi z)
# \end{equation}
#
# (Source is built on reference, it's not a divergence)
#
# BIG QUESTION: STENCIL OF 1ST DERIVATIVE HAS ORDER OF CONV 1. WE GOT TWO ANYWAY!!!

# %%
#LAPLACIAN_Z CONVERGENCE PLOT Re  = 10, delta_t = 0.01, N = 20, 40, 80, 160

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120, 160])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.113222, 0.0271131, 0.00670631, 0.00297471, 0.00167212])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %% [markdown]
# Validation of the divergence operator:
#
# $$\nabla\cdot \mathbf{U} = F$$
#
# The reference field $u_i = \cos(2.0 \pi x) \cdot \sin(4.0 \pi y) \cdot \sin(8.0 \pi z)$:
#
# Expected F is:
#
# \begin{equation}
# F(x, y, z) = -2\pi \cos(4\pi y) \cos(8\pi z) \sin(2\pi x) - 4\pi \cos(2\pi x) \cos(8\pi z) \sin(4\pi y) - 8\pi \cos(2\pi x) \cos(4\pi y) \sin(8\pi z)
# \end{equation}
#
# BIG QUESTION: STENCIL OF 1ST DERIVATIVE FW/BW HAS ORDER OF CONV 1. WE GOT TWO ANYWAY!!!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120, 125])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.056768, 0.0144012, 0.0036135, 0.00160709, 0.00148116])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
#Converegcne of first mixed

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 130])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.432941, 0.105482, 0.0272317, 0.0107118])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
#Converegcne of first mixed

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 130])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.350766, 0.110891, 0.030977, 0.0124494])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
#Converegcne of first mixed

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 130])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.259712, 0.0916493, 0.0301806, 0.0138982])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 160])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0528228, 0.0160158, 0.00507834, 0.00167921])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**1
expected_errors = C / (refinements**1)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected First Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.165671, 0.0470404, 0.013441, 0.00659396])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**1
expected_errors = C / (refinements**1)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected First Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.514606, 0.164598, 0.0497422, 0.0269657])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**1
expected_errors = C / (refinements**1)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Expected First Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
#Convergence test stokes

import matplotlib.pyplot as plt

# Given data (execution times and number of processors)
execution_times = [33.9244, 30.5031, 24.1212, 20.4598]
processors = [1, 2, 3, 4]

# Calculate speedup relative to 1 processor
speedup = [execution_times[0] / time for time in execution_times]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(processors, speedup, marker='o', linestyle='-', color='b', linewidth=2, markersize=8)
plt.xlabel('Number of Processors')
plt.ylabel('Speedup')
plt.title('Speedup vs. Number of Processors')
plt.grid(True)
plt.xticks(processors)
plt.yticks([1] + speedup)  # Include 1 as a tick on the y-axis
plt.tight_layout()
plt.show()

# %%
##stokes multiple steps n = 100 no leaks
#Convergence test stokes

import matplotlib.pyplot as plt

# Given data (execution times and number of processors)
execution_times = [53.0227, 45.2153, 38.919, 35.6195]
processors = [1, 2, 3, 4]

# Calculate speedup relative to 1 processor
speedup = [execution_times[0] / time for time in execution_times]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(processors, speedup, marker='o', linestyle='-', color='b', linewidth=2, markersize=8)
plt.xlabel('Number of Processors')
plt.ylabel('Speedup')
plt.title('Speedup vs. Number of Processors')
plt.grid(True)
plt.xticks(processors)
plt.yticks([1] + speedup)  # Include 1 as a tick on the y-axis
plt.tight_layout()
plt.show()

# %%
##RISULTATO ESTREMEMENTE IMPORTANTE SE delta_s = 60 e delta_t  = 0.1 DIVERGE IL PROBLEMA DI STOKES PROBABILE A CAUSE DI UPDATE ESPLICITO. iMPOSTATO A dt = 0.01 converge
## ok con delta_s = 80-100 delta_t = 0.1 (bene per vedere decadimento).

# %%
##convergence test non linear first equation

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0652721, 0.020003, 0.00550312, 0.00255326])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Non-Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
##convergence test non linear second equation
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0691559, 0.0216421, 0.00603202, 0.00282033])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Non-Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
##convergence test non linear third equation
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0289136, 0.00952197, 0.0029328, 0.00158963])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Non-Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()

# %%
##convergence test non linear first equation periodic

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FixedLocator

# Define the refinement levels
refinements = np.array([20, 40, 80, 120])

# Initialize an array to store the errors for each refinement level
errors = np.array([0.0652721, 0.020003, 0.00550312, 0.00255326])

# Compute the expected second-order errors for comparison
# Assume some constant C for the proportionality, using the error from the first refinement level
C = errors[0] * refinements[0]**2
expected_errors = C / (refinements**2)

# Plot the convergence error
plt.figure()
plt.loglog(refinements, errors, '-o', color='orange', linewidth=2, markersize=8, label='Computed Error')
plt.loglog(refinements, expected_errors, '--', color='green', linewidth=2, markersize=8, label='Non-Expected Second Order Error')

# Set the x-axis ticks to the refinement levels
plt.xticks(refinements, labels=refinements)

# Ensure the x-axis labels are displayed as integers without scientific notation
ax = plt.gca()
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_major_locator(FixedLocator(refinements))
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.get_major_formatter().set_scientific(False)

plt.grid(True, which="both", ls="--")
plt.xlabel('Refinement Level')
plt.ylabel('Error')
plt.title('Convergence Error on Refinement Level')
plt.legend()

plt.show()
